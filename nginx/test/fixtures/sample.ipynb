# %% [markdown]
# # Notebook demo
#
# ## Overview

# %%
print('hello')
raise ValueError('boom')
# Out:
# hello
# Traceback
# ValueError: boom
# <table>...</table>

# %% [markdown]
# ## Overview

# %% [raw]
# a raw cell
